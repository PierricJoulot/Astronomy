# %% [markdown]
# # Study of [EPIC248029954](https://exofop.ipac.caltech.edu/k2/edit_target.php?id=248029954)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from lightkurve import search_lightcurvefile
from lightkurve import search_targetpixelfile
from astropy.stats import BoxLeastSquares
import matplotlib.pyplot as plt
import math

target = '248029954'

tpf = search_targetpixelfile(target).download()
tpf.plot()
lc = search_lightcurvefile(target).download().PDCSAP_FLUX.remove_nans()
lc.plot()
corr_lc = lc.to_corrector("sff").correct(windows=40)
corr_lc_f, trend = corr_lc.flatten(window_length=401, return_trend=True)
corr_lc_f.scatter()

# %% [markdown]
# ### Super flare!
#
# <img src="ktwo248029954-c13_lpd-targ.fits.gz.gif" alt=" " title=" " />
